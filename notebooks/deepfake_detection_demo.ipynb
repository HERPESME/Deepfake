# %% [markdown]
# # Deepfake Detection Demo
#
# This notebook demonstrates the complete deepfake detection pipeline including:
# - Data preprocessing
# - Model training
# - Evaluation
# - Explainability analysis
# - Report generation
